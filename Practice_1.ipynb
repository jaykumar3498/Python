# %% [markdown]
# <a href="https://colab.research.google.com/github/jaykumar3498/Python/blob/main/Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime

# %%
students = ['Alice','Bob','Emily','Charlie']
scores = [90,80,65,50]

# %%
exam = pd.DataFrame({"Name":students,"Scores":scores})
exam
# Out:
#       Name  Scores
# 0    Alice      90
# 1      Bob      80
# 2    Emily      65
# 3  Charlie      50

# %%
exam.loc[0,'Scores']
# Out:
# 90

# %%
exam.loc[2,'Name']
# Out:
# 'Emily'

# %%
exam.loc[:,'Scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: Scores, dtype: int64

# %%
exam.iloc[0,1]
# Out:
# 90

# %%
exam['Name']
# Out:
# 0      Alice
# 1        Bob
# 2      Emily
# 3    Charlie
# Name: Name, dtype: object

# %%
gender = ['Female','Male','Female','Male']
exam['gender'] = gender

# %%
exam
# Out:
#       Name  Scores  gender
# 0    Alice      90  Female
# 1      Bob      80    Male
# 2    Emily      65  Female
# 3  Charlie      50    Male

# %%
exam.drop('Name',axis=1)
# Out:
#    Scores  gender
# 0      90  Female
# 1      80    Male
# 2      65  Female
# 3      50    Male

# %%
exam
# Out:
#       Name  Scores  gender
# 0    Alice      90  Female
# 1      Bob      80    Male
# 2    Emily      65  Female
# 3  Charlie      50    Male

# %%
exam.columns
# Out:
# Index(['Name', 'Scores', 'gender'], dtype='object')

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Scores  4 non-null      int64
#  2   gender  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
exam.describe()
# Out:
#        Scores
# count    4.00
# mean    71.25
# std     17.50
# min     50.00
# 25%     61.25
# 50%     72.50
# 75%     82.50
# max     90.00

# %%
exam.rename({'Name':'Firstname'},axis=1)
# Out:
#   Firstname  Scores  gender
# 0     Alice      90  Female
# 1       Bob      80    Male
# 2     Emily      65  Female
# 3   Charlie      50    Male

# %%
sparse = pd.DataFrame({'a':[1,2,3],'b':[np.nan,4,np.nan],'c':[5,np.nan,np.nan]})
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.isna()
# Out:
#        a      b      c
# 0  False   True  False
# 1  False  False   True
# 2  False   True   True

# %%
sparse.isnull()
# Out:
#        a      b      c
# 0  False   True  False
# 1  False  False   True
# 2  False   True   True

# %%
sparse.fillna(0)
# Out:
#    a    b    c
# 0  1  0.0  5.0
# 1  2  4.0  0.0
# 2  3  0.0  0.0

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.fillna(0)
# Out:
#    a    b    c
# 0  1  0.0  5.0
# 1  2  4.0  0.0
# 2  3  0.0  0.0

# %%
sparse.dropna(axis=1)
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
exam.groupby('Scores').sum()
# Out:
#            Name  gender
# Scores
# 50      Charlie    Male
# 65        Emily  Female
# 80          Bob    Male
# 90        Alice  Female

# %%
exam.groupby('gender').mean()
# Out:
#         Scores
# gender
# Female    77.5
# Male      65.0

# %%
lis = [1,2,1,2]
exam.groupby(lis).get_group(1)
# Out:
#     Name  Scores  gender
# 0  Alice      90  Female
# 2  Emily      65  Female

# %%
exam.groupby(lis).get_group(2)
# Out:
#       Name  Scores gender
# 1      Bob      80   Male
# 3  Charlie      50   Male

# %%
exam['Scores'] > 70
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: Scores, dtype: bool

# %%
exam[exam['Scores'] > 70]
# Out:
#     Name  Scores  gender
# 0  Alice      90  Female
# 1    Bob      80    Male

# %%
filter = exam['Scores']>70
exam.groupby(filter).mean()
# Out:
#         Scores
# Scores
# False     57.5
# True      85.0

# %%
contacts = pd.DataFrame({'Name' :['Alice','Charlie'] ,'Tel'  :['+91 999 999 99 99', '+91 888 888 88 88']})

# %%
contacts
# Out:
#       Name                Tel
# 0    Alice  +91 999 999 99 99
# 1  Charlie  +91 888 888 88 88

# %%
exam.merge(contacts, left_on='Name', right_on='Name')
# Out:
#       Name  Scores  gender                Tel
# 0    Alice      90  Female  +91 999 999 99 99
# 1  Charlie      50    Male  +91 888 888 88 88

# %%
exam.merge(contacts, left_on='Name', right_on ='Name', how ='outer')
# Out:
#       Name  Scores  gender                Tel
# 0    Alice      90  Female  +91 999 999 99 99
# 1      Bob      80    Male                NaN
# 2    Emily      65  Female                NaN
# 3  Charlie      50    Male  +91 888 888 88 88
